# %%
import matplotlib.pyplot as plt
import numpy as np

mean = [0, 0]
cov = [[1.96, 0], [0,1.96]]

x, y = np.random.multivariate_normal(mean, cov, 10000).T
plt.plot(x, y, 'x')
plt.axis('equal')
plt.show()
